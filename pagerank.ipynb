# %% [markdown]
# # Page Rank

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np

# %%
#G = nx.Graph()
#G.add_edge('A', 'B', weight=4)
#G.add_edge('B', 'D', weight=2)
#G.add_edge('A', 'C', weight=3)
#G.add_edge('C', 'D', weight=4)
#nx.shortest_path(G, 'A', 'D', weight='weight')

# %%
#G = nx.read_edgelist('data/facebook_combined.txt')
#G = nx.read_pajek('data/football.net')
#G = nx.read_pajek('data/football.paj')
#G = nx.read_gml('data/karate.gml')
#G = nx.read_graphml('data/wikipedia.graphml)
#G = nx.read_pajek('data/soc-karate.mtx')

#print(nx.info(G))
#print(nx.number_of_nodes(G))
#print(nx.number_of_edges(G))
#print(nx.is_directed(G))

# %%
G = nx.karate_club_graph()
print("Node Degree")
for v in G:
    print('%s %s' % (v, G.degree(v)))
# Out:
# Node Degree
# 0 16
# 1 9
# 2 10
# 3 6
# 4 3
# 5 4
# 6 4
# 7 4
# 8 5
# 9 2
# 10 3
# 11 1
# 12 2
# 13 5
# 14 2
# 15 2
# 16 2
# 17 2
# 18 2
# 19 3
# 20 2
# 21 2
# 22 2
# 23 5
# 24 3
# 25 3
# 26 2
# 27 4
# 28 3
# 29 4
# 30 4
# 31 6
# 32 12
# 33 17

# %%
nx.draw(G, with_labels=True)

# %%
nx.draw_circular(G, with_labels=True)

# %%
nx.degree(G)
# Out:
# DegreeView({0: 16, 1: 9, 2: 10, 3: 6, 4: 3, 5: 4, 6: 4, 7: 4, 8: 5, 9: 2, 10: 3, 11: 1, 12: 2, 13: 5, 14: 2, 15: 2, 16: 2, 17: 2, 18: 2, 19: 3, 20: 2, 21: 2, 22: 2, 23: 5, 24: 3, 25: 3, 26: 2, 27: 4, 28: 3, 29: 4, 30: 4, 31: 6, 32: 12, 33: 17})

# %%
G = nx.DiGraph(nx.path_graph(4))
pr = nx.pagerank(G, alpha=0.9)
nx.draw(G, with_labels=True)
nx.info(G)
# Out:
# 'Name: \nType: DiGraph\nNumber of nodes: 4\nNumber of edges: 6\nAverage in degree:   1.5000\nAverage out degree:   1.5000'

# %% [markdown]
# dataset : http://vlado.fmf.uni-lj.si/pub/networks/data/Ucinet/UciData.htm
